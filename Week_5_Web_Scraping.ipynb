# %% [markdown]
# # Connecting to Google Drive

# %% [markdown]
# # Web Scraping

# %%
import urllib.request
import os
from bs4 import BeautifulSoup
import time

# %%
print(os.getcwd())
# os.chdir('...')
# Out:
# c:\Users\Nova\Documents\Code

# %% [markdown]
# ## Example, back to Dept History

# %%
# url = 'https://www.sta.cuhk.edu.hk/about-us/department-history/'
url = 'https://kyalan.github.io/kytest/department-history.html'
req = urllib.request.Request(url)
resp = urllib.request.urlopen(req)

# %%
content = resp.read()

# If needed to print or process the content, you can do so here
print(content)
# Out:
# b'\n<!DOCTYPE html>\n<html dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">\n\t<head>\n\t\t<meta charset="UTF-8" />\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\t\t\n\t\t<link rel="pingback" href="https://www.sta.cuhk.edu.hk/xmlrpc.php" />\n\n\t\t<script type="text/javascript" defer>document.documentElement.className = \'js\';</script>\n\t\t<!---<script type="text/javascript" src="magicthumb/magicthumb.js"></script>--->\n\n\t\t<!-- Compressed CSS -->\n\t\t\n<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation.min.css" integrity="sha256-ogmFxjqiTMnZhxCqVmcqTvjfe1Y/ec4WaRj/aQPvn+I=" crossorigin="anonymous" defer>\n\n\t\t<link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css" defer/> \n\t\t\n\t\t<!---<link rel="preload" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation.min.css" as="style" integrity="sha256-ogmFxjqiTMnZhxCqVmcqTvjfe1Y/ec4WaRj/aQPvn+I=" crossorigin="anonymous" />\n\n\t\t<link rel="preload" href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css" as="style" />--->\n\n\n\t\t<!-- Compressed JavaScript \n<script src="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/js/foundation.min.js" integrity="sha256-pRF3zifJRA9jXGv++b06qwtSqX1byFQOLjqa2PTEb2o=" crossorigin="anonymous"></script>\n-->\n\n\n\t\t<!-- foundation-float.min.css: Compressed CSS with legacy Float Grid -->\n\t\t<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation-float.min.css" integrity="sha256-4ldVyEvC86/kae2IBWw+eJrTiwNEbUUTmN0zkP4luL4=" crossorigin="anonymous" defer>\n\n\t\t<!-- foundation-prototype.min.css: Compressed CSS with prototyping classes -->\n\t\t<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation-prototype.min.css" integrity="sha256-BiKflOunI0SIxlTOOUCQ0HgwXrRrRwBkIYppEllPIok=" crossorigin="anonymous" defer>\n\n\t\t<!-- foundation-rtl.min.css: Compressed CSS with right-to-left reading direction -->\n\t\t<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation-rtl.min.css" integrity="sha256-F+9Ns8Z/1ZISonBbojH743hsmF3x3AlQdJEeD8DhQsE=" crossorigin="anonymous" defer>\n\t\t\n\t\t\n\t\t<!---<link rel="preload" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation-float.min.css" as="style" integrity="sha256-4ldVyEvC86/kae2IBWw+eJrTiwNEbUUTmN0zkP4luL4=" crossorigin="anonymous"/>\n\t\t\n\t\t<link rel="preload" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation-prototype.min.css" as="style" integrity="sha256-BiKflOunI0SIxlTOOUCQ0HgwXrRrRwBkIYppEllPIok=" crossorigin="anonymous"  />\n\n\t\t<link rel="preload" href="https://cdn.jsdelivr.net/npm/foundation-sites@6.6.3/dist/css/foundation-rtl.min.css" as="style" integrity="sha256-F+9Ns8Z/1ZISonBbojH743hsmF3x3AlQdJEeD8DhQsE=" crossorigin="anonymous" />--->\n\n\t\t<script>var et_site_url=\'https://www.sta.cuhk.edu.hk\';var et_post_id=\'6936\';function et_core_page_resource_fallback(a,b){"undefined"===typeof b&&(b=a.sheet.cssRules&&0===a.sheet.cssRules.length);b&&(a.onerror=null,a.onload=null,a.href?a.href=et_site_url+"/?et_core_page_resource="+a.id+et_post_id:a.src&&(a.src=et_site_url+"/?et_core_page_resource="+a.id+et_post_id))}\n</script><title>Department History - STA, CUHK</title>\n\n\t\t<!-- All in One SEO 4.7.7 - aioseo.com -->\n\t<meta name="description" content="Chair&#039;s Message Department History Newsletters Honours and Awards Contact Us Chair&#039;s Message Department History Newsletters Honours and Awards Contact Us Department History The Department of Statistics and Data Science (\xe2\x80\x9cthe Department\xe2\x80\x9d) at the Chinese University of Hong Kong (CUHK) was founded in 1982. In fact, statistical activities at CUHK predate the formation of the Department." />\n\t<meta name="robots" content="max-image-preview:large" />\n\t<link rel=" ...

# %%
# print(dir(req))
resp.__dict__
# Out:
# {'fp': None,
#  'debuglevel': 0,
#  '_method': 'GET',
#  'headers': <http.client.HTTPMessage at 0x21738387c50>,
#  'msg': 'OK',
#  'version': 11,
#  'status': 200,
#  'reason': 'OK',
#  'chunked': False,
#  'chunk_left': 'UNKNOWN',
#  'length': 0,
#  'will_close': True,
#  'code': 200,
#  'url': 'https://kyalan.github.io/kytest/department-history.html'}

# %%
# Or directly
resp = urllib.request.urlopen(url)

html = ''
if resp.status==200:   html = resp.read()
print(len(html))
# Out:
# 67041

# %%
html[:100]
# Out:
# b'\n<!DOCTYPE html>\n<html dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">\n\t<head>\n\t\t<meta chars'

# %%
type(html)
# Out:
# bytes

# %%
soup = BeautifulSoup(html, 'html.parser')
tag_table = soup.table
print(tag_table)
# Out:
# <table border="1" cellpadding="3" cellspacing="0">
# <tbody>
# <tr>
# <th style="text-align: left; background-color: #ccc1d9;" width="23%">Year</th>
# <th style="text-align: left; background-color: #ccc1d9;" width="77%">History</th>
# </tr>
# <tr class="odd">
# <td>1979</td>
# <td>Statistics (STAT) Programme was set up as an individual programme of study.</td>
# </tr>
# <tr class="odd">
# <td>1981</td>
# <td>Establishment of Division of Statistics at Graduate School, CUHK.</td>
# </tr>
# <tr class="odd">
# <td>1982</td>
# <td>Foundation of the Department. 17 students were enrolled in the first year with Prof. Howell Tong as the chairman</td>
# </tr>
# <tr class="odd">
# <td>1986</td>
# <td>Professor Sik-yum Lee assumed the duty of chairman of the Department.</td>
# </tr>
# <tr class="odd">
# <td>1993</td>
# <td>Professor Nai Ng Chan became the third chairman of the Department.</td>
# </tr>
# <tr class="odd">
# <td>1994</td>
# <td>The Department office relocated from Science Centre to the current site – Lady Shaw Building.</td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>Professor Wing-hung Wong served as the chairman of the Department.</td>
# </tr>
# <tr class="odd">
# <td>1998</td>
# <td>Professor Yeh Lam succeeded Professor Wing-hong Wong and took up the chairmanship of the Department.</td>
# </tr>
# <tr class="odd">
# <td>1999</td>
# <td>Risk Management Science (RMSC) stream was launched. Professor Kim Hung Li assumed the chairmanship for one year.</td>
# </tr>
# <tr class="odd">
# <td>2000</td>
# <td>Professor Jian Qing Fan served as the seventh chairman of the Department.</td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>Risk Management Science (RMSC) was expanded to be an individual programme of study.</td>
# </tr>
# <tr class="odd">
# <td></td>
# <td>The first batch of students majoring in RMSC was enrolled.</td>
# </tr>
# <tr class="odd">
# <td>2004</td>
# <td>Professor Ngai Hang Chan was inaugurated as the Department chairman.</td>
# </tr>
# <tr class="odd">
# <td>2009</td>
# <td>The Department first offered a double-major programme in Quantitative Finance and Risk Management Science (QFRM).</td>
# </tr>
# <tr class="odd">
# <td>2012</td>
# <td>Corresponding to the new 3-3-4 curriculum, the undergraduate programme in Statistics joined Science Faculty broad-based admission scheme.</td>
# </tr>
# <tr class="odd">
# <td>2013</td>
# <td>Professor Qi Man Shao was inaugurated as the Department chairman.</td>
# </tr>
# <tr class="odd">
# <td>2018</td>
# <td>Professor Xinyuan Song was inaugurated as the Department chair.</td>
# </tr>
# <tr class="odd">
# <td>2022</td>
# <td>B.Sc. in Computational Data Science was launched.</td>
# </tr>
# <tr class="odd">
# <td>2024</td>
# <td>M.Sc. in Advanced Studies in Statistics and Data Science was launched.</td>
# </tr>
# <tr class="odd">
# <td>2024</td>
# <td>Professor Junhui Wang was inaugurated as the Department chair.</td>
# </tr>
# <tr class="odd">
# <td>2025</td>
# <td>The Department was renamed the “Department of Statistics and Data Science”.</td>
# </tr>
# </tbody>
# </table>

# %%
soup.find_all('tr')
# Out:
# [<tr>
#  <th style="text-align: left; background-color: #ccc1d9;" width="23%">Year</th>
#  <th style="text-align: left; background-color: #ccc1d9;" width="77%">History</th>
#  </tr>,
#  <tr class="odd">
#  <td>1979</td>
#  <td>Statistics (STAT) Programme was set up as an individual programme of study.</td>
#  </tr>,
#  <tr class="odd">
#  <td>1981</td>
#  <td>Establishment of Division of Statistics at Graduate School, CUHK.</td>
#  </tr>,
#  <tr class="odd">
#  <td>1982</td>
#  <td>Foundation of the Department. 17 students were enrolled in the first year with Prof. Howell Tong as the chairman</td>
#  </tr>,
#  <tr class="odd">
#  <td>1986</td>
#  <td>Professor Sik-yum Lee assumed the duty of chairman of the Department.</td>
#  </tr>,
#  <tr class="odd">
#  <td>1993</td>
#  <td>Professor Nai Ng Chan became the third chairman of the Department.</td>
#  </tr>,
#  <tr class="odd">
#  <td>1994</td>
#  <td>The Department office relocated from Science Centre to the current site – Lady Shaw Building.</td>
#  </tr>,
#  <tr class="odd">
#  <td></td>
#  <td>Professor Wing-hung Wong served as the chairman of the Department.</td>
#  </tr>,
#  <tr class="odd">
#  <td>1998</td>
#  <td>Professor Yeh Lam succeeded Professor Wing-hong Wong and took up the chairmanship of the Department.</td>
#  </tr>,
#  <tr class="odd">
#  <td>1999</td>
#  <td>Risk Management Science (RMSC) stream was launched. Professor Kim Hung Li assumed the chairmanship for one year.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2000</td>
#  <td>Professor Jian Qing Fan served as the seventh chairman of the Department.</td>
#  </tr>,
#  <tr class="odd">
#  <td></td>
#  <td>Risk Management Science (RMSC) was expanded to be an individual programme of study.</td>
#  </tr>,
#  <tr class="odd">
#  <td></td>
#  <td>The first batch of students majoring in RMSC was enrolled.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2004</td>
#  <td>Professor Ngai Hang Chan was inaugurated as the Department chairman.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2009</td>
#  <td>The Department first offered a double-major programme in Quantitative Finance and Risk Management Science (QFRM).</td>
#  </tr>,
#  <tr class="odd">
#  <td>2012</td>
#  <td>Corresponding to the new 3-3-4 curriculum, the undergraduate programme in Statistics joined Science Faculty broad-based admission scheme.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2013</td>
#  <td>Professor Qi Man Shao was inaugurated as the Department chairman.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2018</td>
#  <td>Professor Xinyuan Song was inaugurated as the Department chair.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2022</td>
#  <td>B.Sc. in Computational Data Science was launched.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2024</td>
#  <td>M.Sc. in Advanced Studies in Statistics and Data Science was launched.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2024</td>
#  <td>Professor Junhui Wang was inaugurated as the Department chair.</td>
#  </tr>,
#  <tr class="odd">
#  <td>2025</td>
#  <td>The Department was renamed the “Department of Statistics and Data Science”.</td>
#  </tr>]

# %%
# Prettify the BeautifulSoup object: pretty_soup
print(tag_table.prettify())
# Out:
# <table border="1" cellpadding="3" cellspacing="0">
#  <tbody>
#   <tr>
#    <th style="text-align: left; background-color: #ccc1d9;" width="23%">
#     Year
#    </th>
#    <th style="text-align: left; background-color: #ccc1d9;" width="77%">
#     History
#    </th>
#   </tr>
#   <tr class="odd">
#    <td>
#     1979
#    </td>
#    <td>
#     Statistics (STAT) Programme was set up as an individual programme of study.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1981
#    </td>
#    <td>
#     Establishment of Division of Statistics at Graduate School, CUHK.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1982
#    </td>
#    <td>
#     Foundation of the Department. 17 students were enrolled in the first year with Prof. Howell Tong as the chairman
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1986
#    </td>
#    <td>
#     Professor Sik-yum Lee assumed the duty of chairman of the Department.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1993
#    </td>
#    <td>
#     Professor Nai Ng Chan became the third chairman of the Department.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1994
#    </td>
#    <td>
#     The Department office relocated from Science Centre to the current site – Lady Shaw Building.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#    </td>
#    <td>
#     Professor Wing-hung Wong served as the chairman of the Department.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1998
#    </td>
#    <td>
#     Professor Yeh Lam succeeded Professor Wing-hong Wong and took up the chairmanship of the Department.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1999
#    </td>
#    <td>
#     Risk Management Science (RMSC) stream was launched. Professor Kim Hung Li assumed the chairmanship for one year.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2000
#    </td>
#    <td>
#     Professor Jian Qing Fan served as the seventh chairman of the Department.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#    </td>
#    <td>
#     Risk Management Science (RMSC) was expanded to be an individual programme of study.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#    </td>
#    <td>
#     The first batch of students majoring in RMSC was enrolled.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2004
#    </td>
#    <td>
#     Professor Ngai Hang Chan was inaugurated as the Department chairman.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2009
#    </td>
#    <td>
#     The Department first offered a double-major programme in Quantitative Finance and Risk Management Science (QFRM).
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2012
#    </td>
#    <td>
#     Corresponding to the new 3-3-4 curriculum, the undergraduate programme in Statistics joined Science Faculty broad-based admission scheme.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2013
#    </td>
#    <td>
#     Professor Qi Man Shao was inaugurated as the Department chairman.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2018
#    </td>
#    <td>
#     Professor Xinyuan Song was inaugurated as the Department chair.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2022
#    </td>
#    <td>
#     B.Sc. in Computational Data Science was launched.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2024
#    </td>
#    <td>
#     M.Sc. in Advanced Studies in Statistics and Data Science was launched.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2024
#    </td>
#    <td>
#     Professor Junhui Wang was inaugurated as the Department chair.
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2025
#    </td>
#    <td>
#     The Department was renamed the “Department of Statistics and Data Science”.
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
tag_rows = tag_table.findAll('tr', {'class':'odd'})
print(tag_rows)
# Out:
# [<tr class="odd">
# <td>1979</td>
# <td>Statistics (STAT) Programme was set up as an individual programme of study.</td>
# </tr>, <tr class="odd">
# <td>1981</td>
# <td>Establishment of Division of Statistics at Graduate School, CUHK.</td>
# </tr>, <tr class="odd">
# <td>1982</td>
# <td>Foundation of the Department. 17 students were enrolled in the first year with Prof. Howell Tong as the chairman</td>
# </tr>, <tr class="odd">
# <td>1986</td>
# <td>Professor Sik-yum Lee assumed the duty of chairman of the Department.</td>
# </tr>, <tr class="odd">
# <td>1993</td>
# <td>Professor Nai Ng Chan became the third chairman of the Department.</td>
# </tr>, <tr class="odd">
# <td>1994</td>
# <td>The Department office relocated from Science Centre to the current site – Lady Shaw Building.</td>
# </tr>, <tr class="odd">
# <td></td>
# <td>Professor Wing-hung Wong served as the chairman of the Department.</td>
# </tr>, <tr class="odd">
# <td>1998</td>
# <td>Professor Yeh Lam succeeded Professor Wing-hong Wong and took up the chairmanship of the Department.</td>
# </tr>, <tr class="odd">
# <td>1999</td>
# <td>Risk Management Science (RMSC) stream was launched. Professor Kim Hung Li assumed the chairmanship for one year.</td>
# </tr>, <tr class="odd">
# <td>2000</td>
# <td>Professor Jian Qing Fan served as the seventh chairman of the Department.</td>
# </tr>, <tr class="odd">
# <td></td>
# <td>Risk Management Science (RMSC) was expanded to be an individual programme of study.</td>
# </tr>, <tr class="odd">
# <td></td>
# <td>The first batch of students majoring in RMSC was enrolled.</td>
# </tr>, <tr class="odd">
# <td>2004</td>
# <td>Professor Ngai Hang Chan was inaugurated as the Department chairman.</td>
# </tr>, <tr class="odd">
# <td>2009</td>
# <td>The Department first offered a double-major programme in Quantitative Finance and Risk Management Science (QFRM).</td>
# </tr>, <tr class="odd">
# <td>2012</td>
# <td>Corresponding to the new 3-3-4 curriculum, the undergraduate programme in Statistics joined Science Faculty broad-based admission scheme.</td>
# </tr>, <tr class="odd">
# <td>2013</td>
# <td>Professor Qi Man Shao was inaugurated as the Department chairman.</td>
# </tr>, <tr class="odd">
# <td>2018</td>
# <td>Professor Xinyuan Song was inaugurated as the Department chair.</td>
# </tr>, <tr class="odd">
# <td>2022</td>
# <td>B.Sc. in Computational Data Science was launched.</td>
# </tr>, <tr class="odd">
# <td>2024</td>
# <td>M.Sc. in Advanced Studies in Statistics and Data Science was launched.</td>
# </tr>, <tr class="odd">
# <td>2024</td>
# <td>Professor Junhui Wang was inaugurated as the Department chair.</td>
# </tr>, <tr class="odd">
# <td>2025</td>
# <td>The Department was renamed the “Department of Statistics and Data Science”.</td>
# </tr>]
# C:\Users\Nova\AppData\Local\Temp\ipykernel_30592\4138549938.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   tag_rows = tag_table.findAll('tr', {'class':'odd'})

# %% [markdown]
# We need to take out all words standing for "Professor", including "Prof.".

# %%
import re

for tag in tag_rows:
  tag_values = tag.find_all('td')
  year = tag_values[0].text
  message = re.findall(r'Prof(?:essor)?\.?(?:\s[A-Z][a-z-]*)+', tag_values[1].text)
  print(year, message)
# Out:
# 1979 []
# 1981 []
# 1982 ['Prof. Howell Tong']
# 1986 ['Professor Sik-yum Lee']
# 1993 ['Professor Nai Ng Chan']
# 1994 []
#  ['Professor Wing-hung Wong']
# 1998 ['Professor Yeh Lam', 'Professor Wing-hong Wong']
# 1999 ['Professor Kim Hung Li']
# 2000 ['Professor Jian Qing Fan']
#  []
#  []
# 2004 ['Professor Ngai Hang Chan']
# 2009 []
# 2012 []
# 2013 ['Professor Qi Man Shao']
# 2018 ['Professor Xinyuan Song']
# 2022 []
# 2024 []
# 2024 ['Professor Junhui Wang']
# 2025 []

# %% [markdown]
# ## Example on Fitness Rooms in LCSD site
#
# ![yuenchaukok_gym.png](https://drive.google.com/uc?export=view&id=1451sSsaHw1ugc2b1CRTxqHMjfYYCYxMu)
#
# Gym rooms are provided by the Leisure and Cultural Services Department (LCSD) in the urban area and the New Territories. Let's access into the information site: https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRooms.do

# %%
import urllib.request, urllib.parse
from urllib.parse import urljoin
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRooms.do'
resp = urllib.request.Request(url=url, headers={'User-Agent': 'Mozilla/5.0'})

html = ''
req = urllib.request.urlopen(resp)
if req.status==200:   html = req.read().decode()
print(f'website retrieved: {len(html)}')
# Out:
# website retrieved: 57604

# %% [markdown]
# Note !
#
# ```
# headers={'User-Agent': 'Mozilla/5.0'}
# ```
# is a must here.

# %%
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# We aim to obtain all rows of tables - \<tr\> tags and \<td\> for each tag

# %%
tags_tr = soup.find_all('tr')
len(tags_tr)
# Out:
# 89

# %%
tags_td = tags_tr[1].find_all('td')

# %%
tags_td
# Out:
# [<td class="venu">Aberdeen Sports Centre</td>,
#  <td class="addr">5/F., Aberdeen Municipal Services Building, 203 Aberdeen Main Road, Aberdeen</td>,
#  <td class="tel">2555 8909 </td>,
#  <td class="detail" width="13%">
#  <a href="/clpss/en/webApp/FitnessRoomDetails.do?id=1374" title="Details">Details</a>
#  </td>]

# %%
rows = []
for tag_tr in tags_tr:
  tags_td = tag_tr.find_all('td')
  row = []
  for tag_td in tags_td:
    value = tag_td.text.strip()
    row.append(value)
  rows.append(row)

# %%
rows
# Out:
# [[],
#  ['Aberdeen Sports Centre',
#   '5/F., Aberdeen Municipal Services Building, 203 Aberdeen Main Road, Aberdeen',
#   '2555 8909',
#   'Details'],
#  ['Aberdeen Tennis and Squash Centre',
#   'No. 1, Aberdeen Praya Road, Hong Kong',
#   '2553 6130',
#   'Details'],
#  ['Ap Lei Chau Sports Centre',
#   '8 Hung Shing Street, Ap Lei Chau',
#   '2554 0832',
#   'Details'],
#  ['Chai Wan Sports Centre',
#   'Yee Shun Street, Chai Wan',
#   '2897 9144',
#   'Details*'],
#  ['Harbour Road Sports Centre',
#   '27 Harbour Road, Wan Chai',
#   '2827 9684',
#   'Details'],
#  ['Hong Kong Park Sports Centre',
#   '29 Cotton Tree Drive, Central',
#   '2521 5072',
#   'Details'],
#  ['Island East Sports Centre',
#   '52 Lei King Road, Sai Wan Ho',
#   '2151 4070',
#   'Details'],
#  ['Java Road Sports Centre',
#   '3/F, Java Road Municipal Services Building, 99 Java Road, North Point',
#   '2516 9415',
#   'Details*'],
#  ['Lockhart Road Sports Centre',
#   '10/F., Lockhart Road Municipal Services Building, 225 Hennessy Road, Wan Chai',
#   '2879 5521',
#   'Details'],
#  ['Quarry Bay Sports Centre',
#   '6/F., Quarry Bay Complex, 38 Quarry Bay Street',
#   '2562 0374',
#   'Details*'],
#  ['Shek Tong Tsui Sports Centre',
#   "5/F., 470 Queen's Road West",
#   '2858 0541',
#   'Details'],
#  ['Sheung Wan Sports Centre',
#   "11/F., 345 Queen's Road Central",
#   '2853 2574',
#   'Details'],
#  ['Smithfield Sports Centre',
#   '4/F, Smithfield Municipal Services Building, 12K Smithfield, Kennedy Town, Hong Kong',
#   '2855 7321',
#   'Details'],
#  ['Sun Yat Sen Memorial Park Sports Centre',
#   '18 Eastern Street North, Western',
#   '2858 2493',
#   'Details'],
#  [],
#  ['Choi Hung Road Sports Centre',
#   '150 Choi Hung Road, Wong Tai Sin',
#   '2326 2714',
#   'Details'],
#  ['Choi Wing Road Sports Centre',
#   '58 Choi Wing Road, Kwun Tong',
#   '2721 5918',
#   'Details*'],
#  ['Chuk Yuen Sports Centre',
#   'Chuk Yuen North Estate, Chuk Yuen Road, Wong Tai Sin',
#   '2324 3960',
#   'Details'],
#  ['Fa Yuen Street Sports Centre',
#   '10/F., Fa Yuen Street Municipal Services Building, 123A Fa Yuen Street, Mongkok',
#   '2395 1501',
#   'Details'],
#  ['Fat Kwong Street Sports Centre',
#   '9/F, 18 Good Shepherd Street, Ho Man Tin, Kowloon',
#   '2712 2652',
#   'Details'],
#  ['Hiu Kwong Street Sports Centre',
#   '2 Hiu Kwong Street, Kwun Tong, Kowloon',
#   '2347 0384',
#   'Details'],
#  ['Ho Man Tin Sports Centre',
#   '1 Chung Yee Street, Ho Man Tin',
#   '2762 7837',
#   'Details*'],
#  ['Hung Hom Municipal Services Building Sports Centre',
#   '3/F, Hung Hom Municipal Services Building,11 Ma Tau Wai Road, Hung Hom, Kowloon.',
#   '2765 0586',
#   'Details'],
#  ['Kowloon Park Sports Centre',
#   '22 Austin Road, Tsim Sha Tsui',
#   '2724 3120/2724 3344',
#   'Details'],
#  ['Kwun Chung Sports Centre',
#   '5/F., Kwun Chung Municipal Services Building, 17 Bowring Street, Jordan',
#   '2302 1275',
#   'Details'],
#  ['Lam Tin South Sports Centre',
#   '170 Pik Wan Road, Lam Tin',
#   '2379 9254',
#   'Details'],
#  ['Lei Yue Mun Sports Centre',
#   '2/F., Lei Yue Mun Municipal Services Building, 6 Lei Yue Mun Path, Yau Tong, Kwun Tong',
#   '2349 3954',
#   'Details'],
#  ['Ngau Tau Kok Road Sports Centre',
#   '4/F, Ngau Tak Kok Municipal Services Building, 183 Ngau Tau Kok Road',
#   '2756 3466',
#   'Details'],
#  ['Pei Ho Street Sports Centre',
#   '5/F., Pei Ho Street Municipal Services Building, 333 Ki Lung Street, Sham Shui Po',
#   '2729 1010',
#   'Details'],
#  ['Po Kong Village Road Sports Centre',
#   '120 Po Kong Village Road, Wong Tai Sin',
#   '2325 3585',
#   'Details'],
#  ['Po On Road Sports Centre',
#   '2/F., Po On Road Municipal Services Building, 325-329 Po On Road, Sham Shui Po',
#   '2729 4237',
#   'Details'],
#  ['Sham Shui Po Sports Centre',
#   '2/F., Sham Shui Po Leisure and Cultural Building, 38 Sham Mong Road, Sham Shui Po, Kowloon',
#   '2360 2276',
#   'Details'],
#  ['Shek Kip Mei Park Sports Centre',
#   '290 Nam Cheong Street, Sham Shui Po',
#   '2784 7424',
#   'Details'],
#  ['Shun Lee Tsuen Sports Centre',
#   'No.33, Shun Lee Tsuen Road, Kwun Tong',
#   '2951 4136',
#   'Details*'],
#  ['Tai Kok Tsui Sports Centre',
#   '6/F., Tai Kok Tsui Municipal Services Building, 63 Fuk Tsun Street, Tai Kok Tsui, Kowloon',
#   '2393 1084',
#   'Details'],
#  ['To Kwa Wan Sports Centre',
#   '66 Ha Heung Road, To Kwa Wan',
#   '2364 9285',
#   'Details'],
#  [],
#  ['Che Kung Temple Sports Centre',
#   '10 Sha Tin Tau Road, Sha Tin',
#   '2790 0221',
#   'Details*'],
#  ['Cheung Chau Sports Centre',
#   '3 Cheung Chau Hospital Road, Cheung Chau',
#   '2981 6285',
#   'Details'],
#  ['Cheung Fat Sports Centre',
#   '4/F., Cheung Fat Plaza, Cheung Fat Estate, Tsing Yi',
#   '2433 5886',
#   'Details'],
#  ['Fu Heng Sports Centre',
#   '1/F., Fu Heng Shopping Centre, Fu Heng Estate, Tai Po',
#   '2665 2753',
#   'Details'],
#  ['Fu Shin Sports Centre',
#   '6/F., Multi Car-Park Building, Fu Shin Estate, Tai Po',
#   '2661 4144',
#   'Details'],
#  ['Fung Kam Street Sports Centre',
#   'Fung Yau Street North, Yuen Long',
#   '2475 2334',
#   'Details'],
#  ['Fung Shue Wo Sports Centre',
#   'Phase II, Tsing Yi Estate, 10 Fung Shue Wo Road, Tsing Yi',
#   '2433 6523',
#   'Details'],
#  ['Hang Hau Sports Centre',
#   '1/F, Sai Kung Tseung Kwan O Government Complex, 38 Pui Shing Road, Tseung Kwan O',
#   '2623 5928',
#   'Details*'],
#  ['Heng On Sports Centre',
#   '4/F., Heng On Commercial Centre, Heng On Estate, Sha Tin',
#   '2642 0203',
#   'Details'],
#  ['Hin Keng Sports Centre',
#   'Hin Keng Commercial Centre, Hin Keng Estate, Sha Tin',
#   '2605 8407',
#   'Details'],
#  ['Hong Kong Velodrome',
#   '107 Po Hong Road, Tseung Kwan O',
#   '2878 8622',
#   'Details*'],
#  ['Lai King Sports Centre',
#   'Lai Cho Road, Lai King, Kwai Chung',
#   '2744 5678',
#   'Details'],
#  ['Leung Tin Sports Centre',
#   '4/F., Carpark Building, Tin King Estate, Tuen Mun',
#   '2467 1594',
#   'Details'],
#  ['Long Ping Sports Centre',
#   '2/F., Long Ping Commercial Centre, Long Ping Estate, Yuen Long',
#   '2475 2404/2475 1444',
#   'Details'],
#  ['Luen Wo Hui Sports Centre',
#   '3/F., 9 Wo Mun Street, Luen Wo Hui, Fanling',
#   '2677 5149',
#   'Details*'],
#  ['Lung Sum Avenue Sports Centre',
#   '155 Jockey Club Road, Sheung Shui',
#   '2673 4433',
#   'Details'],
#  ['Ma On Shan Sports Centre',
#   '14 On Chun Street, Ma On Shan, N.T.',
#   '2631 1597',
#   'Details*'],
#  ['Mei Lam Sports Centre', 'Mei Lam Estate, Sha Tin', '2695 9318', 'Details'],
#  ['Mui Wo Sports Centre',
#   'Mui Wo Municipal Services Building, 9 Ngan Shek Street, Mui Wo',
#   '2984 2334',
#   'Details'],
#  ['North Kwai Chung Tang Shiu Kin Sports Centre',
#   '292 Wo Yi Hop Road, Kwai Chung',
#   '2426 3269',
#   'Details'],
#  ['Osman Ramju Sadick Memorial Sports Centre',
#   '176 Hing Fong Road, Kwai Chung',
#   '2422 5610',
#   'Details'],
#  ['Peng Chau Sports Centre',
#   'Peng Chau Municipal Services Building, 6 Po Ping Street, Peng Chau',
#   '2983 8420',
#   'Details'],
#  ['Po Lam Sports Centre',
#   'Po Lam Estate, Tseung Kwan O',
#   '2701 5918',
#   'Details'],
#  ['Po Wing Road Sports Centre',
#   '19 Pak Wo Road, Sheung Shui',
#   '2639 2979',
#   'Details*'],
#  ['Siu Lun Sports Centre',
#   '3/F, Tuen Mun Siu Lun Government Complex, 19 Siu Lun Street, Tuen Mun, N.T.',
#   '2659 2311',
#   'Details'],
#  ['Tai Hing Sports Centre',
#   'Tsing Chung Koon Road, Tuen Mun',
#   '2463 1260',
#   'Details'],
#  ['Tai Po Hui Sports Centre',
#   '6/F., Tai Po Complex, 8 Heung Sze Wui Street, Tai Po',
#   '3183 9011',
#   'Details'],
#  ['Tai Po Sports Centre', '13 Ting Tai Road, Tai Po', '2664 7222', 'Details'],
#  ['Tai Wo Hau Sports Centre',
#   'Tai Ha Street, Tai Wo Hau Estate, Kwai Chung',
#   '2920 2011',
#   'Details'],
#  ['Tai Wo Sports Centre',
#   'Podium Level, Tai Wo Shopping Centre, Tai Wo Estate, Tai Po',
#   '2656 3398',
#   'Details'],
#  ['The Jockey Club Tuen Mun Butterfly Beach Sports Centre',
#   'Wu Shan Road, Tuen Mun',
#   '2465 7610',
#   'Details'],
#  ['Tin Fai Road Sports Centre',
#   '63 Tin Shui Road, Tin Shui Wai, NT',
#   '2473 0229',
#   'Details*'],
#  ['Tin Ping Sports Centre',
#   '3/F., Tin Ping Estate Shopping Centre, Tin Ping Estate, Sheung Shui',
#   '2673 3699',
#   'Details'],
#  ['Tin Shui Sports Centre',
#   '7 Tin Shui Road, Tin Shui Wai, Yuen Long',
#   '2446 6609',
#   'Details*'],
#  ['Tin Shui Wai Sports Centre',
#   '1 Tin Pak Road, Tin Shui Wai',
#   '2446 4778',
#   'Details'],
#  ['Tiu Keng Leng Sports Centre',
#   '2 Chui Ling Road, Tseung Kwan O',
#   '2481 5033',
#   'Details*'],
#  ['Tseung Kwan O Sports Centre',
#   '9 Wan Lung Road, Tseung Kwan O',
#   '2701 2317',
#   'Details'],
#  ['Tsing Yi Southwest Sports Centre',
#   '70 Chung Mei Road, Tsing Yi, N.T.',
#   '2341 0102',
#   'Details*'],
#  ['Tsing Yi Sports Centre',
#   '2/F., Tsing Yi Municipal Services Building, 38 Tsing Luk Street, Tsing Yi',
#   '2495 4631',
#   'Details'],
#  ['Tsuen Wan Sports Centre',
#   '53 Wing Shun Street, Tsuen Wan, New Territories',
#   '2392 9570',
#   'Details'],
#  ['Tsuen Wan West Sports Centre',
#   '68 Hoi On Street, Tsuen Wan',
#   '2412 0904',
#   'Details'],
#  ['Tsui Lam Sports Centre',
#   'Tsui Lam Estate, Tseung Kwan O',
#   '2703 1137',
#   'Details'],
#  ['Tung Cheong Street Sports Centre',
#   '3/F, Tai Po Tung Cheong Street Leisure Building, 25 Tung Cheong Street, Tai Po',
#   '2691 2055',
#   'Details'],
#  ['Tung Chung Man Tung Road Sports Centre',
#   '2/F Tung Chung Municipal Services Building, 39 Man Tung Road, Tung Chung, N.T.',
#   '2109 2421',
#   'Details'],
#  ['Wai Tsuen Sports Centre',
#   '6 Miu Kong Street, Tsuen Wan',
#   '2415 2621',
#   'Details'],
#  ['Wo Hing Sports Centre', '8 Wo Ming Lane, Fanling', '2669 7057', 'Details'],
#  ['Yau Oi Sports Centre', 'Hing On Lane, Tuen Mun', '2450 8850', 'Details'],
#  ['Yeung Uk Road Sports Centre',
#   '4/F., Yeung Uk Road Municipal Services Building, 45 Yeung Uk Road, Tsuen Wan',
#   '2415 4445',
#   'Details'],
#  ['Yuen Chau Kok Sports Centre',
#   '35 Ngan Shing Street, Sha Tin, N.T.',
#   '2509 9108',
#   'Details*'],
#  ['Yuen Long Sports Centre',
#   '3/F, Yuen Long Leisure and Cultural Building, 52 Ma Tin Road, Yuen Long',
#   '2891 9207',
#   'Details*'],
#  ['Yuen Wo Road Sports Centre',
#   '8 Yuen Wo Road, Sha Tin',
#   '2604 5987',
#   'Details']]

# %% [markdown]
# The link in html may be in form of relative link, says "/clpss/en/webApp/FitnessRoomDetails.do?id=1374" <br>
# You can use urljoin with serviceurl = "https://www.lcsd.gov.hk" for making a full link.

# %%
serviceurl = 'https://www.lcsd.gov.hk'

dict_tags = []
for tag in tags_tr:
    tags_td = tag.find_all('td')
    if len(tags_td) != 4: continue
    dict_tag = {}
    dict_tag['venu'] = tags_td[0].text
    dict_tag['addr'] = tags_td[1].text
    dict_tag['tel'] = tags_td[2].text
    dict_tag['link'] = urljoin(serviceurl, tags_td[3].a.get('href'))
    dict_tags.append(dict_tag)

# %%
dict_tags
# Out:
# [{'venu': 'Aberdeen Sports Centre',
#   'addr': '5/F., Aberdeen Municipal Services Building, 203 Aberdeen Main Road, Aberdeen',
#   'tel': '2555 8909 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1374'},
#  {'venu': 'Aberdeen Tennis and Squash Centre',
#   'addr': 'No. 1, Aberdeen Praya Road, Hong Kong',
#   'tel': '2553 6130 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1375'},
#  {'venu': 'Ap Lei Chau Sports Centre ',
#   'addr': '8 Hung Shing Street, Ap Lei Chau',
#   'tel': '2554 0832',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1376'},
#  {'venu': 'Chai Wan Sports Centre',
#   'addr': 'Yee Shun Street, Chai Wan',
#   'tel': '2897 9144 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1365'},
#  {'venu': 'Harbour Road Sports Centre',
#   'addr': '27 Harbour Road, Wan Chai',
#   'tel': '2827 9684',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1440'},
#  {'venu': 'Hong Kong Park Sports Centre',
#   'addr': '29 Cotton Tree Drive, Central',
#   'tel': '2521 5072',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1369'},
#  {'venu': 'Island East Sports Centre',
#   'addr': '52 Lei King Road, Sai Wan Ho',
#   'tel': '2151 4070',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1367'},
#  {'venu': 'Java Road Sports Centre',
#   'addr': '3/F, Java Road Municipal Services Building, 99 Java Road, North Point',
#   'tel': '2516 9415',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2931'},
#  {'venu': 'Lockhart Road Sports Centre',
#   'addr': '10/F., Lockhart Road Municipal Services Building, 225 Hennessy Road, Wan Chai ',
#   'tel': '2879 5521 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1368'},
#  {'venu': 'Quarry Bay Sports Centre',
#   'addr': '6/F., Quarry Bay Complex, 38 Quarry Bay Street',
#   'tel': '2562 0374 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1366'},
#  {'venu': 'Shek Tong Tsui Sports Centre',
#   'addr': "5/F., 470 Queen's Road West",
#   'tel': '2858 0541 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1370'},
#  {'venu': 'Sheung Wan Sports Centre',
#   'addr': "11/F., 345 Queen's Road Central",
#   'tel': '2853 2574 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1371'},
#  {'venu': 'Smithfield Sports Centre',
#   'addr': '4/F, Smithfield Municipal Services Building, 12K Smithfield, Kennedy Town, Hong Kong',
#   'tel': '2855 7321 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1372'},
#  {'venu': 'Sun Yat Sen Memorial Park Sports Centre',
#   'addr': '18 Eastern Street North, Western',
#   'tel': '2858 2493',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1373'},
#  {'venu': 'Choi Hung Road Sports Centre',
#   'addr': '150 Choi Hung Road, Wong Tai Sin',
#   'tel': '2326 2714 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1384'},
#  {'venu': 'Choi Wing Road Sports Centre',
#   'addr': '58 Choi Wing Road, Kwun Tong',
#   'tel': '2721 5918',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2517'},
#  {'venu': 'Chuk Yuen Sports Centre',
#   'addr': 'Chuk Yuen North Estate, Chuk Yuen Road, Wong Tai Sin',
#   'tel': '2324 3960',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1386'},
#  {'venu': 'Fa Yuen Street Sports Centre',
#   'addr': '10/F., Fa Yuen Street Municipal Services Building, 123A Fa Yuen Street, Mongkok',
#   'tel': '2395 1501 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1387'},
#  {'venu': 'Fat Kwong Street Sports Centre',
#   'addr': '9/F, 18 Good Shepherd Street, Ho Man Tin, Kowloon',
#   'tel': '2712 2652',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1378'},
#  {'venu': 'Hiu Kwong Street Sports Centre',
#   'addr': '2 Hiu Kwong Street, Kwun Tong, Kowloon',
#   'tel': '2347 0384',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2763'},
#  {'venu': 'Ho Man Tin Sports Centre',
#   'addr': '1 Chung Yee Street, Ho Man Tin',
#   'tel': '2762 7837',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1379'},
#  {'venu': 'Hung Hom Municipal Services Building Sports Centre',
#   'addr': '3/F, Hung Hom Municipal Services Building,11 Ma Tau Wai Road, Hung Hom, Kowloon.',
#   'tel': '2765 0586',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2987'},
#  {'venu': 'Kowloon Park Sports Centre',
#   'addr': '22 Austin Road, Tsim Sha Tsui',
#   'tel': '2724 3120/2724 3344 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1388'},
#  {'venu': 'Kwun Chung Sports Centre',
#   'addr': '5/F., Kwun Chung Municipal Services Building, 17 Bowring Street, Jordan',
#   'tel': '2302 1275 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1389'},
#  {'venu': 'Lam Tin South Sports Centre',
#   'addr': '170 Pik Wan Road, Lam Tin',
#   'tel': '2379 9254 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1381'},
#  {'venu': 'Lei Yue Mun Sports Centre',
#   'addr': '2/F., Lei Yue Mun Municipal Services Building, 6 Lei Yue Mun Path, Yau Tong, Kwun Tong',
#   'tel': '2349 3954 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1383'},
#  {'venu': 'Ngau Tau Kok Road Sports Centre',
#   'addr': '4/F, Ngau Tak Kok Municipal Services Building, 183 Ngau Tau Kok Road',
#   'tel': '2756 3466 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1380'},
#  {'venu': 'Pei Ho Street Sports Centre',
#   'addr': '5/F., Pei Ho Street Municipal Services Building, 333 Ki Lung Street, Sham Shui Po',
#   'tel': '2729 1010 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1391'},
#  {'venu': 'Po Kong Village Road Sports Centre',
#   'addr': '120 Po Kong Village Road, Wong Tai Sin',
#   'tel': '2325 3585 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1385'},
#  {'venu': 'Po On Road Sports Centre',
#   'addr': '2/F., Po On Road Municipal Services Building, 325-329 Po On Road, Sham Shui Po',
#   'tel': '2729 4237 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1392'},
#  {'venu': 'Sham Shui Po Sports Centre',
#   'addr': '2/F., Sham Shui Po Leisure and Cultural Building, 38 Sham Mong Road, Sham Shui Po, Kowloon',
#   'tel': '2360 2276',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2754'},
#  {'venu': 'Shek Kip Mei Park Sports Centre',
#   'addr': '290 Nam Cheong Street, Sham Shui Po',
#   'tel': '2784 7424 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1393'},
#  {'venu': 'Shun Lee Tsuen Sports Centre',
#   'addr': 'No.33, Shun Lee Tsuen Road, Kwun Tong',
#   'tel': '2951 4136 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1382'},
#  {'venu': 'Tai Kok Tsui Sports Centre',
#   'addr': '6/F., Tai Kok Tsui Municipal Services Building, 63 Fuk Tsun Street, Tai Kok Tsui, Kowloon',
#   'tel': '2393 1084',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1390'},
#  {'venu': 'To Kwa Wan Sports Centre',
#   'addr': '66 Ha Heung Road, To Kwa Wan',
#   'tel': '2364 9285 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1377'},
#  {'venu': 'Che Kung Temple Sports Centre',
#   'addr': '10 Sha Tin Tau Road, Sha Tin',
#   'tel': '2790 0221',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2261'},
#  {'venu': 'Cheung Chau Sports Centre',
#   'addr': '3 Cheung Chau Hospital Road, Cheung Chau',
#   'tel': '2981 6285 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1416'},
#  {'venu': 'Cheung Fat Sports Centre',
#   'addr': '4/F., Cheung Fat Plaza, Cheung Fat Estate, Tsing Yi',
#   'tel': '2433 5886 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1422'},
#  {'venu': 'Fu Heng Sports Centre',
#   'addr': '1/F., Fu Heng Shopping Centre, Fu Heng Estate, Tai Po',
#   'tel': '2665 2753 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1410'},
#  {'venu': 'Fu Shin Sports Centre',
#   'addr': '6/F., Multi Car-Park Building, Fu Shin Estate, Tai Po',
#   'tel': '2661 4144',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1409'},
#  {'venu': 'Fung Kam Street Sports Centre',
#   'addr': 'Fung Yau Street North, Yuen Long',
#   'tel': '2475 2334 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1434'},
#  {'venu': 'Fung Shue Wo Sports Centre',
#   'addr': 'Phase II, Tsing Yi Estate, 10 Fung Shue Wo Road, Tsing Yi',
#   'tel': '2433 6523 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1423'},
#  {'venu': 'Hang Hau Sports Centre',
#   'addr': '1/F, Sai Kung Tseung Kwan O Government Complex, 38 Pui Shing Road, Tseung Kwan O',
#   'tel': '2623 5928',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1399'},
#  {'venu': 'Heng On Sports Centre',
#   'addr': '4/F., Heng On Commercial Centre, Heng On Estate, Sha Tin',
#   'tel': '2642 0203 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1412'},
#  {'venu': 'Hin Keng Sports Centre',
#   'addr': 'Hin Keng Commercial Centre, Hin Keng Estate, Sha Tin',
#   'tel': '2605 8407 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1413'},
#  {'venu': 'Hong Kong Velodrome',
#   'addr': '107 Po Hong Road, Tseung Kwan O',
#   'tel': '2878 8622',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1395'},
#  {'venu': 'Lai King Sports Centre',
#   'addr': 'Lai Cho Road, Lai King, Kwai Chung',
#   'tel': '2744 5678 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1420'},
#  {'venu': 'Leung Tin Sports Centre',
#   'addr': '4/F., Carpark Building, Tin King Estate, Tuen Mun',
#   'tel': '2467 1594 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1426'},
#  {'venu': 'Long Ping Sports Centre',
#   'addr': '2/F., Long Ping Commercial Centre, Long Ping Estate, Yuen Long',
#   'tel': '2475 2404/2475 1444 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1437'},
#  {'venu': 'Luen Wo Hui Sports Centre',
#   'addr': '3/F., 9 Wo Mun Street, Luen Wo Hui, Fanling',
#   'tel': '2677 5149',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1402'},
#  {'venu': 'Lung Sum Avenue Sports Centre',
#   'addr': '155 Jockey Club Road, Sheung Shui',
#   'tel': '2673 4433',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1403'},
#  {'venu': 'Ma On Shan Sports Centre',
#   'addr': '14 On Chun Street, Ma On Shan, N.T.',
#   'tel': '2631 1597 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1415'},
#  {'venu': 'Mei Lam Sports Centre',
#   'addr': 'Mei Lam Estate, Sha Tin',
#   'tel': '2695 9318',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1414'},
#  {'venu': 'Mui Wo Sports Centre',
#   'addr': 'Mui Wo Municipal Services Building, 9 Ngan Shek Street, Mui Wo',
#   'tel': '2984 2334 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1417'},
#  {'venu': 'North Kwai Chung Tang Shiu Kin Sports Centre',
#   'addr': '292 Wo Yi Hop Road, Kwai Chung',
#   'tel': '2426 3269 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1421'},
#  {'venu': 'Osman Ramju Sadick Memorial Sports Centre',
#   'addr': '176 Hing Fong Road, Kwai Chung',
#   'tel': '2422 5610 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1424'},
#  {'venu': 'Peng Chau Sports Centre',
#   'addr': 'Peng Chau Municipal Services Building, 6 Po Ping Street, Peng Chau',
#   'tel': '2983 8420 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1418'},
#  {'venu': 'Po Lam Sports Centre',
#   'addr': 'Po Lam Estate, Tseung Kwan O',
#   'tel': '2701 5918',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1396'},
#  {'venu': 'Po Wing Road Sports Centre',
#   'addr': '19 Pak Wo Road, Sheung Shui',
#   'tel': '2639 2979 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1405'},
#  {'venu': 'Siu Lun Sports Centre',
#   'addr': '3/F, Tuen Mun Siu Lun Government Complex, 19 Siu Lun Street, Tuen Mun, N.T.',
#   'tel': '2659 2311',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2194'},
#  {'venu': 'Tai Hing Sports Centre',
#   'addr': 'Tsing Chung Koon Road, Tuen Mun',
#   'tel': '2463 1260 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1427'},
#  {'venu': 'Tai Po Hui Sports Centre',
#   'addr': '6/F., Tai Po Complex, 8 Heung Sze Wui Street, Tai Po',
#   'tel': '3183 9011',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1407'},
#  {'venu': 'Tai Po Sports Centre',
#   'addr': '13 Ting Tai Road, Tai Po',
#   'tel': '2664 7222',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1406'},
#  {'venu': 'Tai Wo Hau Sports Centre',
#   'addr': 'Tai Ha Street, Tai Wo Hau Estate, Kwai Chung',
#   'tel': '2920 2011 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1419'},
#  {'venu': 'Tai Wo Sports Centre',
#   'addr': 'Podium Level, Tai Wo Shopping Centre, Tai Wo Estate, Tai Po',
#   'tel': '2656 3398 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1408'},
#  {'venu': 'The Jockey Club Tuen Mun Butterfly Beach Sports Centre',
#   'addr': 'Wu Shan Road, Tuen Mun',
#   'tel': '2465 7610 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1429'},
#  {'venu': 'Tin Fai Road Sports Centre',
#   'addr': '63 Tin Shui Road, Tin Shui Wai, NT',
#   'tel': '2473 0229 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1436'},
#  {'venu': 'Tin Ping Sports Centre',
#   'addr': '3/F., Tin Ping Estate Shopping Centre, Tin Ping Estate, Sheung Shui',
#   'tel': '2673 3699 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1404'},
#  {'venu': 'Tin Shui Sports Centre',
#   'addr': '7 Tin Shui Road, Tin Shui Wai, Yuen Long',
#   'tel': '2446 6609 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1435'},
#  {'venu': 'Tin Shui Wai Sports Centre',
#   'addr': '1 Tin Pak Road, Tin Shui Wai',
#   'tel': '2446 4778 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1433'},
#  {'venu': 'Tiu Keng Leng Sports Centre',
#   'addr': '2 Chui Ling Road, Tseung Kwan O',
#   'tel': '2481 5033',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1400'},
#  {'venu': 'Tseung Kwan O Sports Centre',
#   'addr': '9 Wan Lung Road, Tseung Kwan O',
#   'tel': '2701 2317',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1398'},
#  {'venu': 'Tsing Yi Southwest Sports Centre',
#   'addr': '70 Chung Mei Road, Tsing Yi, N.T.',
#   'tel': '2341 0102',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2221'},
#  {'venu': 'Tsing Yi Sports Centre',
#   'addr': '2/F., Tsing Yi Municipal Services Building, 38 Tsing Luk Street, Tsing Yi',
#   'tel': '2495 4631 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1425'},
#  {'venu': 'Tsuen Wan Sports Centre',
#   'addr': '53 Wing Shun Street, Tsuen Wan, New Territories',
#   'tel': '2392 9570',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2118'},
#  {'venu': 'Tsuen Wan West Sports Centre',
#   'addr': '68 Hoi On Street, Tsuen Wan',
#   'tel': '2412 0904 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1432'},
#  {'venu': 'Tsui Lam Sports Centre',
#   'addr': 'Tsui Lam Estate, Tseung Kwan O',
#   'tel': '2703 1137',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1397'},
#  {'venu': 'Tung Cheong Street Sports Centre',
#   'addr': '3/F, Tai Po Tung Cheong Street Leisure Building, 25 Tung Cheong Street, Tai Po',
#   'tel': '2691 2055',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=2734'},
#  {'venu': 'Tung Chung Man Tung Road Sports Centre',
#   'addr': '2/F Tung Chung Municipal Services Building, 39 Man Tung Road, Tung Chung, N.T.',
#   'tel': '2109 2421 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1438'},
#  {'venu': 'Wai Tsuen Sports Centre',
#   'addr': '6 Miu Kong Street, Tsuen Wan',
#   'tel': '2415 2621 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1431'},
#  {'venu': 'Wo Hing Sports Centre',
#   'addr': '8 Wo Ming Lane, Fanling',
#   'tel': '2669 7057 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1401'},
#  {'venu': 'Yau Oi Sports Centre',
#   'addr': 'Hing On Lane, Tuen Mun',
#   'tel': '2450 8850 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1428'},
#  {'venu': 'Yeung Uk Road Sports Centre',
#   'addr': '4/F., Yeung Uk Road Municipal Services Building, 45 Yeung Uk Road, Tsuen Wan',
#   'tel': '2415 4445 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1430'},
#  {'venu': 'Yuen Chau Kok Sports Centre',
#   'addr': '35 Ngan Shing Street, Sha Tin, N.T.',
#   'tel': '2509 9108',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1394'},
#  {'venu': 'Yuen Long Sports Centre',
#   'addr': '3/F, Yuen Long Leisure and Cultural Building, 52 Ma Tin Road, Yuen Long',
#   'tel': '2891 9207',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1447'},
#  {'venu': 'Yuen Wo Road Sports Centre',
#   'addr': '8 Yuen Wo Road, Sha Tin',
#   'tel': '2604 5987 ',
#   'link': 'https://www.lcsd.gov.hk/clpss/en/webApp/FitnessRoomDetails.do?id=1411'}]

# %%
df_url = pd.DataFrame(dict_tags)

# %%
df_url
# Out:
#                                  venu  \
# 0              Aberdeen Sports Centre
# 1   Aberdeen Tennis and Squash Centre
# 2          Ap Lei Chau Sports Centre
# 3              Chai Wan Sports Centre
# 4          Harbour Road Sports Centre
# ..                                ...
# 81               Yau Oi Sports Centre
# 82        Yeung Uk Road Sports Centre
# 83        Yuen Chau Kok Sports Centre
# 84            Yuen Long Sports Centre
# 85         Yuen Wo Road Sports Centre
#
#                                                  addr         tel  \
# 0   5/F., Aberdeen Municipal Services Building, 20...  2555 8909
# 1               No. 1, Aberdeen Praya Road, Hong Kong  2553 6130
# 2                    8 Hung Shing Street, Ap Lei Chau   2554 0832
# 3                           Yee Shun Street, Chai Wan  2897 9144
# 4                           27 Harbour Road, Wan Chai   2827 9684
# ..                                                ...         ...
# 81                             Hing On Lane, Tuen Mun  2450 8850
# 82  4/F., Yeung Uk Road Municipal Services Buildin...  2415 4445
# 83                35 Ngan Shing Street, Sha Tin, N.T.   2509 9108
# 84  3/F, Yuen Long Leisure and Cultural Building, ...   2891 9207
# 85                            8 Yuen Wo Road, Sha Tin  2604 5987
#
#                                                  link
# 0   https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 1   https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 2   https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 3   https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 4   https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# ..                                                ...
# 81  https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 82  https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 83  https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 84  https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
# 85  https://www.lcsd.gov.hk/clpss/en/webApp/Fitnes...
#
# [86 rows x 4 columns]

# %% [markdown]
# # Why google search url cannot be worked?

# %%
# url = 'https://www.google.com/search?q=japanese+onsen&tbm=isch'
url = 'https://www.google.com/search?q=japanese+onsen'
req = urllib.request.urlopen(url)

# %%
req.read()
# Out:
# b'<!DOCTYPE html><html lang="zh-HK"><head><title>Google Search</title><style>body{background-color:#fff}</style><script nonce="PQgWPBiIOkaoE7xKKSPnJA">window.google = window.google || {};window.google.c = window.google.c || {cap:0};</script></head><body><noscript><style>table,div,span,p{display:none}</style><meta content="0;url=/httpservice/retry/enablejs?sei=Bq3naN34HpKl0PEPz8_gqQM" http-equiv="refresh"><div style="display:block">&#33509;&#24744;&#22312;&#25976;&#31186;&#20839;&#20173;&#26410;&#33021;&#33258;&#21205;&#36339;&#36681;&#65292;&#35531;&#40670;&#25802;<a href="/httpservice/retry/enablejs?sei=Bq3naN34HpKl0PEPz8_gqQM">&#36889;&#35023;</a>&#12290;</div></noscript><script nonce="PQgWPBiIOkaoE7xKKSPnJA">(function(){var sctm=false;(function(){sctm&&google.tick("load","pbsst");}).call(this);})();</script><script nonce="PQgWPBiIOkaoE7xKKSPnJA">//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==\n(function(){var E=function(C,d,T,Z,e,J,W,N,A,P){{A=d;while(A!=33)if(A==67){if((W=(N=Y.trustedTypes,Z),N)&&N.createPolicy){try{W=N.createPolicy(J,{createHTML:x,createScript:x,createScriptURL:x})}catch(l){if(Y.console)Y.console[e](l.message)}P=W}else P=W;A=2}else{if(A==2)return P;A==d?A=49:A==39?A=T+7&3?2:67:A==49?A=T-C<<2>=T&&(T+5&42)<T?23:39:A==23&&(P=Z,A=39)}}},x=function(C){return E.call(this,8,27,11,C)},Y=this||self;(0,eval)(function(C,d){return(d=E(8,27,5,null,"error","ks"))&&C.eval(d.createScript("1"))===1?function(T){return d.createScript(T)}:function(T){return""+T}}(Y)(Array(Math.random()*7824|0).join("\\n")+[\'//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==\',\n\'(function(){/*\',\n\'\',\n\' Copyright Google LLC\',\n\' SPDX-License-Identifier: Apache-2.0\',\n\'*/\',\n\'var lF=function(T,A,d,C,Y,N,x,P,e){{P=49;while(P!=20)if(P==24)P=(A^10)<16&&(A>>1&7)>=5?75:82;else if(P==14)d.ym=function(){return d.zR?d.zR:d.zR=new d},d.zR=void 0,P=6;else if(P==75)N.classList?N.classList.remove(x):(N.classList?N.classList.contains(x):w(26,d,x,J7(9,3,Y,N)))&&h(Y,44,N,Array.prototype.filter.call(J7(9,7,Y,N),function(J){return J!=x}).join(C)),P=82;else if(P==61)P=(A&T)==A?80:24;else{if(P==6)return e;P==80?(x=C,x^=x<<13,x^=x>>17,x=(N=x<<5,2*(N|0)+2*~x+(x|~N)-3*(~x|N)),(x&=Y)||(x=1),e=d^x,P=24):P==82?P=(A>>1&2)>=1&&((A^32)&14)<5?14:6:P==49&&(P=61)}}},RK=function(T,A,d,C,Y,N,x,P,e,J,l,W,E,Z){for(E=33;E!=73;)if(E==38)E=T+3&7?44:12;else if(E==12)d.kt=A,d.listener=null,d.proxy=null,d.src=null,d.fY=null,E=44;else if(E==33)E=93;else if(E==93)E=T>>2&7?38:58;else if(E==58){if(P=N.u.i[String(C)]){for(e=(W=(P=P.concat(),A),0);e<P.length;++e)(x=P[e])&&!x.kt&&x.capture==d&&(J=x.listener,l=x.fY||x.src,x.IA&&Qp(N.u,x,24,A),W=J.call(l,Y)!==false&&W);Z=W&&!Y.defaultPrevented}else Z=A;E=38}else if(E==44)return Z},el=function(T,A,d,C,Y,N,x,P,e,J,l){{l=72;while(l!=51)if(l==30)e=C in bF?bF[C]:bF[C]=d+C,l=32;else if(l==0)l=(A|48)==A?30:32;else if(l==89)l=(A|72)==A?63:23;else if(l==79)J=function(){},P=void 0,x=t7(d,function(W,E){for(E=61;E!=22;)E==61?E=J?81:22:E==81&&(C&&vb(C),P=W,J(),J=void 0,E=22)},!!C),Y=x[0],N=x[1],e={top:function(W,E,Z,G,a,B,v){for(B=92;B!=20;)if(B==30)B=E?60:53;else{if(B==53)return G=Y(Z),W&&W(G),G;B==60?B=P?87:97:B==87?(v(),B=20):B==92?(v=function(){P(function(t){vb(function(){W(t)})},Z)},B=30):B==97&&(a=J,J=function(){(a(),vb)(v)},B=20)}},pe:function(W){N&&N(W)}},l=0;else{if(l==T)return e;if(l==78)typeof d==="function"?e=d:(d[h7]||(d[h7]=function(W){return d.handleEvent(W)}),e=d[h7]),l=T;else if(l==63)l=d.classList?53:60;else if(l==77){a:{for(x in Y)if(N.call(void 0,Y[x],x,Y)){e=d;break a}e=C}l=31}else if(l==72)l=89;else if(l==23)l=(A&19)==A?79:0;else if(l==5 ...

# %% [markdown]
# Also, some of sites do not work...

# %%
url = 'https://www.skyscanner.com.hk/transport/flights/hkg/lond/?null&oym=2512&selectedoday=21&iym=2512&selectediday=31'
req = urllib.request.urlopen(url)
html = req.read()

# %%
print(BeautifulSoup(html, 'html.parser').prettify())

# %% [markdown]
# tag list: https://www.w3schools.com/tags/ref_byfunc.asp
